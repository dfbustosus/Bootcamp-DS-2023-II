# %% [markdown]
# # Carga de datos

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns 
# %matplotlib inline
data = 'https://raw.githubusercontent.com/dfbustosus/Curso_DS_para_todos/main/Data/Live.csv'
df = pd.read_csv(data)
df
# Out:
#                               status_id status_type status_published  \
# 0      246675545449582_1649696485147474       video   4/22/2018 6:00
# 1      246675545449582_1649426988507757       photo  4/21/2018 22:45
# 2      246675545449582_1648730588577397       video   4/21/2018 6:17
# 3      246675545449582_1648576705259452       photo   4/21/2018 2:29
# 4      246675545449582_1645700502213739       photo   4/18/2018 3:22
# ...                                 ...         ...              ...
# 7045  1050855161656896_1061863470556065       photo   9/24/2016 2:58
# 7046  1050855161656896_1061334757275603       photo  9/23/2016 11:19
# 7047  1050855161656896_1060126464063099       photo  9/21/2016 23:03
# 7048  1050855161656896_1058663487542730       photo   9/20/2016 0:43
# 7049  1050855161656896_1050858841656528       photo  9/10/2016 10:30
#
#       num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# ...

# %% [markdown]
# Podemos ver que hay 7050 instancias y 16 atributos en el conjunto de datos. En la descripción del conjunto de datos, se indica que hay 7051 instancias y 12 atributos en el conjunto de datos.
#
# Entonces, podemos inferir que la primera instancia es el encabezado de la fila y hay 4 atributos adicionales en el conjunto de datos. A continuación, debemos echar un vistazo al conjunto de datos para obtener más información al respecto.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7050 entries, 0 to 7049
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   status_id         7050 non-null   object
#  1   status_type       7050 non-null   object
#  2   status_published  7050 non-null   object
#  3   num_reactions     7050 non-null   int64
#  4   num_comments      7050 non-null   int64
#  5   num_shares        7050 non-null   int64
#  6   num_likes         7050 non-null   int64
#  7   num_loves         7050 non-null   int64
#  8   num_wows          7050 non-null   int64
#  9   num_hahas         7050 non-null   int64
#  10  num_sads          7050 non-null   int64
#  11  num_angrys        7050 non-null   int64
#  12  Column1           0 non-null      float64
#  13  Column2           0 non-null      float64
#  14  Column3           0 non-null      float64
#  15  Column4           0 non-null      float64
# ...

# %%
df.isnull().sum()
# Out:
# status_id              0
# status_type            0
# status_published       0
# num_reactions          0
# num_comments           0
# num_shares             0
# num_likes              0
# num_loves              0
# num_wows               0
# num_hahas              0
# num_sads               0
# num_angrys             0
# Column1             7050
# Column2             7050
# Column3             7050
# Column4             7050
# dtype: int64

# %%
# Borrar columnas redundantes
df.drop(['Column1', 'Column2', 'Column3', 'Column4'], axis=1, inplace=True)

# %% [markdown]
# Podemos ver que hay 3 variables de caracteres (tipo de datos = objeto) y las 9 variables numéricas restantes (tipo de datos = int64).

# %%
df.describe()
# Out:
#        num_reactions  num_comments   num_shares    num_likes    num_loves  \
# count    7050.000000   7050.000000  7050.000000  7050.000000  7050.000000
# mean      230.117163    224.356028    40.022553   215.043121    12.728652
# std       462.625309    889.636820   131.599965   449.472357    39.972930
# min         0.000000      0.000000     0.000000     0.000000     0.000000
# 25%        17.000000      0.000000     0.000000    17.000000     0.000000
# 50%        59.500000      4.000000     0.000000    58.000000     0.000000
# 75%       219.000000     23.000000     4.000000   184.750000     3.000000
# max      4710.000000  20990.000000  3424.000000  4710.000000   657.000000
#
#           num_wows    num_hahas     num_sads   num_angrys
# count  7050.000000  7050.000000  7050.000000  7050.000000
# mean      1.289362     0.696454     0.243688     0.113191
# std       8.719650     3.957183     1.597156     0.726812
# min       0.000000     0.000000     0.000000     0.000000
# ...

# %%
len(df['status_id'].unique())
# Out:
# 6997

# %% [markdown]
# Podemos ver que hay 6997 etiquetas únicas en la variable status_id. El número total de instancias en el conjunto de datos es 7050. Por lo tanto, es aproximadamente un identificador único para cada una de las instancias. Por lo tanto, esta no es una variable que podamos usar.

# %%
len(df['status_published'].unique())
# Out:
# 6913

# %% [markdown]
# Nuevamente, podemos ver que hay 6913 etiquetas únicas en la variable status_published. El número total de instancias en el conjunto de datos es 7050. Por lo tanto, también es aproximadamente un identificador único para cada una de las instancias. Por lo tanto, esta no es una variable que podamos usar.

# %%
df['status_type'].unique()
# Out:
# array(['video', 'photo', 'link', 'status'], dtype=object)

# %%
len(df['status_type'].unique())
# Out:
# 4

# %% [markdown]
# # Borrado de columnas

# %%
df.drop(['status_id', 'status_published'], axis=1, inplace=True)

# %%
df=df.drop_duplicates()
df.shape
# Out:
# (4987, 10)

# %%
df
# Out:
#      status_type  num_reactions  num_comments  num_shares  num_likes  \
# 0          video            529           512         262        432
# 1          photo            150             0           0        150
# 2          video            227           236          57        204
# 3          photo            111             0           0        111
# 4          photo            213             0           0        204
# ...          ...            ...           ...         ...        ...
# 7044       photo             86             0           0         86
# 7045       photo             89             0           0         89
# 7046       photo             16             0           0         14
# 7047       photo              2             0           0          1
# 7048       photo            351            12          22        349
#
#       num_loves  num_wows  num_hahas  num_sads  num_angrys
# 0            92         3          1         1           0
# ...

# %% [markdown]
# # Separado de variables

# %%
X = df
#y = df['status_type']

# %%
X.head()
# Out:
#   status_type  num_reactions  num_comments  num_shares  num_likes  num_loves  \
# 0       video            529           512         262        432         92
# 1       photo            150             0           0        150          0
# 2       video            227           236          57        204         21
# 3       photo            111             0           0        111          0
# 4       photo            213             0           0        204          9
#
#    num_wows  num_hahas  num_sads  num_angrys
# 0         3          1         1           0
# 1         0          0         0           0
# 2         1          1         0           0
# 3         0          0         0           0
# 4         0          0         0           0

# %%
import warnings
#warnings.filterwarnings("ignore")
#from sklearn.preprocessing import LabelEncoder
#le = LabelEncoder()
#X['status_type'] = le.fit_transform(X['status_type'])
#y = le.transform(y)
#X.head()

# %% [markdown]
# # Feature Scaling

# %%
cols_num=[x for x in X.columns if x!='status_type']
cols_num
# Out:
# ['num_reactions',
#  'num_comments',
#  'num_shares',
#  'num_likes',
#  'num_loves',
#  'num_wows',
#  'num_hahas',
#  'num_sads',
#  'num_angrys']

# %%
import warnings
warnings.filterwarnings("ignore")
from sklearn.preprocessing import MinMaxScaler
ms = MinMaxScaler()
X[cols_num] = ms.fit_transform(X[cols_num])
X.head()
# Out:
#   status_type  num_reactions  num_comments  num_shares  num_likes  num_loves  \
# 0       video       0.112314      0.024393    0.076519   0.091720   0.140030
# 1       photo       0.031847      0.000000    0.000000   0.031847   0.000000
# 2       video       0.048195      0.011243    0.016647   0.043312   0.031963
# 3       photo       0.023567      0.000000    0.000000   0.023567   0.000000
# 4       photo       0.045223      0.000000    0.000000   0.043312   0.013699
#
#    num_wows  num_hahas  num_sads  num_angrys
# 0  0.010791   0.006369  0.019608         0.0
# 1  0.000000   0.000000  0.000000         0.0
# 2  0.003597   0.006369  0.000000         0.0
# 3  0.000000   0.000000  0.000000         0.0
# 4  0.000000   0.000000  0.000000         0.0

# %%
X=X.drop(columns='status_type')
X.head()
# Out:
#    num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 0       0.112314      0.024393    0.076519   0.091720   0.140030  0.010791
# 1       0.031847      0.000000    0.000000   0.031847   0.000000  0.000000
# 2       0.048195      0.011243    0.016647   0.043312   0.031963  0.003597
# 3       0.023567      0.000000    0.000000   0.023567   0.000000  0.000000
# 4       0.045223      0.000000    0.000000   0.043312   0.013699  0.000000
#
#    num_hahas  num_sads  num_angrys
# 0   0.006369  0.019608         0.0
# 1   0.000000  0.000000         0.0
# 2   0.006369  0.000000         0.0
# 3   0.000000  0.000000         0.0
# 4   0.000000  0.000000         0.0

# %%
X.shape
# Out:
# (4987, 9)

# %% [markdown]
# # Algoritmo base

# %%
from sklearn.cluster import KMeans
#KMeans?

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=4, random_state=42) 
kmeans.fit(X)
# Out:
# KMeans(n_clusters=4, random_state=42)

# %%
kmeans.cluster_centers_
# Out:
# array([[3.18282459e-02, 2.96902375e-03, 3.71554504e-03, 3.05859830e-02,
#         6.94406086e-03, 2.57908592e-03, 2.10923053e-03, 3.46892789e-03,
#         1.95109261e-03],
#        [3.92866866e-01, 2.89101253e-03, 4.48821468e-03, 3.91906457e-01,
#         3.50523771e-03, 7.26830300e-03, 9.92881229e-04, 7.49711649e-04,
#         1.89753321e-04],
#        [2.89870429e-01, 1.30267194e-01, 2.08508931e-01, 2.24908229e-01,
#         3.79692457e-01, 1.39548175e-01, 8.56598607e-02, 4.36137072e-02,
#         6.60235152e-02],
#        [6.44926729e-02, 8.46566130e-02, 7.63067978e-02, 4.67707452e-02,
#         1.16015263e-01, 6.77290336e-03, 2.31392811e-02, 2.31386261e-02,
#         1.74825175e-02]])

# %% [markdown]
# # Verificar que tan bien hace las clasificaciones

# %%
labels = kmeans.labels_
labels
# Out:
# array([3, 0, 0, ..., 0, 0, 0])

# %%
df['Label'] = kmeans.labels_
df
# Out:
#      status_type  num_reactions  num_comments  num_shares  num_likes  \
# 0          video       0.112314      0.024393    0.076519   0.091720
# 1          photo       0.031847      0.000000    0.000000   0.031847
# 2          video       0.048195      0.011243    0.016647   0.043312
# 3          photo       0.023567      0.000000    0.000000   0.023567
# 4          photo       0.045223      0.000000    0.000000   0.043312
# ...          ...            ...           ...         ...        ...
# 7044       photo       0.018259      0.000000    0.000000   0.018259
# 7045       photo       0.018896      0.000000    0.000000   0.018896
# 7046       photo       0.003397      0.000000    0.000000   0.002972
# 7047       photo       0.000425      0.000000    0.000000   0.000212
# 7048       photo       0.074522      0.000572    0.006425   0.074098
#
#       num_loves  num_wows  num_hahas  num_sads  num_angrys  Label
# 0      0.140030  0.010791   0.006369  0.019608         0.0      3
# ...

# %% [markdown]
# # Mejorando este algoritmo

# %%
from sklearn.cluster import KMeans
cs = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(X)
    cs.append(kmeans.inertia_)
plt.plot(range(1, 11), cs)
plt.title('Metodo del codo')
plt.xlabel('Clusters')
plt.ylabel('CS')
plt.show()

# %%
#!pip install -q yellowbrick

# %%
import warnings
warnings.filterwarnings("ignore")
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer
model = KMeans()
visualizer = KElbowVisualizer(model, k=(2,12))
visualizer.fit(X)  
visualizer.show()
# Out:
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
kmeans = KMeans(n_clusters=4, random_state=42)
kmeans.fit(X)

labels = kmeans.labels_

# %%
labels
# Out:
# array([3, 0, 0, ..., 0, 0, 0])

# %% [markdown]
# # Descripcion de etiquetas

# %%
ms.inverse_transform(X[cols_num])
# Out:
# array([[0.11231423, 0.02439257, 0.07651869, ..., 0.00636943, 0.01960784,
#         0.        ],
#        [0.03184713, 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.04819533, 0.01124345, 0.0166472 , ..., 0.00636943, 0.        ,
#         0.        ],
#        ...,
#        [0.00339703, 0.        , 0.        , ..., 0.00636943, 0.        ,
#         0.        ],
#        [0.00042463, 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.07452229, 0.0005717 , 0.00642523, ..., 0.        , 0.        ,
#         0.        ]])

# %%
X_new=pd.DataFrame(ms.inverse_transform(X[cols_num]),columns=cols_num)
X_new['labels']=labels
X_new.head()
# Out:
#    num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 0       0.112314      0.024393    0.076519   0.091720   0.140030  0.010791
# 1       0.031847      0.000000    0.000000   0.031847   0.000000  0.000000
# 2       0.048195      0.011243    0.016647   0.043312   0.031963  0.003597
# 3       0.023567      0.000000    0.000000   0.023567   0.000000  0.000000
# 4       0.045223      0.000000    0.000000   0.043312   0.013699  0.000000
#
#    num_hahas  num_sads  num_angrys  labels
# 0   0.006369  0.019608         0.0       3
# 1   0.000000  0.000000         0.0       0
# 2   0.006369  0.000000         0.0       0
# 3   0.000000  0.000000         0.0       0
# 4   0.000000  0.000000         0.0       0

# %%
X_new.groupby(by='labels').mean()
# Out:
#         num_reactions  num_comments  num_shares  num_likes  num_loves  \
# labels
# 0            0.031829      0.002967    0.003707   0.030590   0.006921
# 1            0.392867      0.002891    0.004488   0.391906   0.003505
# 2            0.289870      0.130267    0.208509   0.224908   0.379692
# 3            0.064430      0.084529    0.076241   0.046714   0.115983
#
#         num_wows  num_hahas  num_sads  num_angrys
# labels
# 0       0.002579   0.002103  0.003470    0.001952
# 1       0.007268   0.000993  0.000750    0.000190
# 2       0.139548   0.085660  0.043614    0.066024
# 3       0.006767   0.023143  0.023098    0.017452
